# %% [markdown]
# # QM640 Capstone — Dataset Verification
#
# Loads the analysis panel and verifies its shape, structure, and completeness. This notebook is `01_data_cleaning_join.ipynb` (verification portion) — the source for the dataset screenshots in the synopsis document.

# %%
import pandas as pd

df = pd.read_excel('QM640_Analysis_Panel_UPDATED.xlsx', sheet_name='Panel_State_FY')
df = df[df['State (ICED name)'].notna()].reset_index(drop=True)
df.shape
# Out:
# (252, 20)

# %%
df.head()
# Out:
#              State (ICED name)       FY  EV registrations  \
# 0  Andaman and Nicobar Islands  2019-20                 5
# 1  Andaman and Nicobar Islands  2020-21               105
# 2  Andaman and Nicobar Islands  2021-22                22
# 3  Andaman and Nicobar Islands  2022-23                23
# 4  Andaman and Nicobar Islands  2023-24                36
#
#    Total registrations (all fuels)  Fuel-based (non-EV) registrations  \
# 0                             8918                               8913
# 1                             5694                               5589
# 2                             5557                               5535
# 3                             7491                               7468
# 4                             8187                               8151
#
#    EV share %  Public chargers (snapshot)  \
# 0    0.000561                         NaN
# 1    0.018440                         NaN
# 2    0.003959                         NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 20 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   State (ICED name)                    252 non-null    str
#  1   FY                                   252 non-null    str
#  2   EV registrations                     252 non-null    int64
#  3   Total registrations (all fuels)      252 non-null    int64
#  4   Fuel-based (non-EV) registrations    252 non-null    int64
#  5   EV share %                           252 non-null    float64
#  6   Public chargers (snapshot)           70 non-null     float64
#  7   Charger snapshot definition & as-on  70 non-null     str
#  8   Energy Requirement (MU)              210 non-null    float64
#  9   Energy Supplied (MU)                 210 non-null    float64
#  10  Energy Deficit %                     210 non-null    float64
# ...

# %%
df.describe()
# Out:
#        EV registrations  Total registrations (all fuels)  \
# count        252.000000                     2.520000e+02
# mean       33113.357143                     6.761541e+05
# std        60570.246277                     8.070481e+05
# min            0.000000                     5.840000e+02
# 25%          208.500000                     3.827700e+04
# 50%         5996.000000                     4.508230e+05
# 75%        41426.750000                     9.990575e+05
# max       414565.000000                     4.263193e+06
#
#        Fuel-based (non-EV) registrations  EV share %  \
# count                       2.520000e+02  252.000000
# mean                        6.430407e+05    0.035862
# std                         7.592643e+05    0.038296
# min                         5.810000e+02    0.000000
# 25%                         3.753200e+04    0.003324
# 50%                         4.490420e+05    0.019324
# 75%                         9.693358e+05    0.064577
# ...

# %%
df.isnull().sum()
# Out:
# State (ICED name)                        0
# FY                                       0
# EV registrations                         0
# Total registrations (all fuels)          0
# Fuel-based (non-EV) registrations        0
# EV share %                               0
# Public chargers (snapshot)             182
# Charger snapshot definition & as-on    182
# Energy Requirement (MU)                 42
# Energy Supplied (MU)                    42
# Energy Deficit %                        42
# PC-NSDP Current Rs (MoSPI)             171
# Urban % (Census 2011)                   28
# Annual Peak Demand (MW)                 21
# Annual Avg Demand (MW)                  21
# Peak-to-Avg Ratio                       21
# Peak-demand YoY growth                  54
# Grid-stress class                       54
# Projected population                     0
# Chargers per 100k population           182
# dtype: int64

# %% [markdown]
# ## Target Variable Distribution (RQ4)
#
# Grid-stress class is the binary target for the RQ4 logistic regression: 1 if a state's year-on-year peak-demand growth exceeds the all-state median growth for that financial year, else 0.

# %%
df['Grid-stress class'].value_counts(dropna=False)
# Out:
# Grid-stress class
# 0.0    102
# 1.0     96
# NaN     54
# Name: count, dtype: int64
